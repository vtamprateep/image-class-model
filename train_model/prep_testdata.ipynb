# %%
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth # Connect Drive to Colab
from oauth2client.client import GoogleCredentials

import shutil
import csv

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# Load and unzip test image file
download = drive.CreateFile({'id': '1RRxv_sKxo5N0UYjwm86mgWRYmijd8fRv'})
download.GetContentFile('seg_test.zip')
# !unzip seg_test.zip
# Out:
# Archive:  seg_test.zip
#    creating: seg_test/
#    creating: seg_test/seg_test/
#    creating: seg_test/seg_test/glacier/
#   inflating: seg_test/seg_test/glacier/21475.jpg
#   inflating: seg_test/seg_test/glacier/21934.jpg
#   inflating: seg_test/seg_test/glacier/20414.jpg
#   inflating: seg_test/seg_test/glacier/21269.jpg
#   inflating: seg_test/seg_test/glacier/20303.jpg
#   inflating: seg_test/seg_test/glacier/21859.jpg
#   inflating: seg_test/seg_test/glacier/21881.jpg
#   inflating: seg_test/seg_test/glacier/20742.jpg
#   inflating: seg_test/seg_test/glacier/23738.jpg
#   inflating: seg_test/seg_test/glacier/21768.jpg
#   inflating: seg_test/seg_test/glacier/20383.jpg
#   inflating: seg_test/seg_test/glacier/23920.jpg
#   inflating: seg_test/seg_test/glacier/23001.jpg
#   inflating: seg_test/seg_test/glacier/23636.jpg
#   inflating: seg_test/seg_test/glacier/21215.jpg
#   inflating: seg_test/seg_test/glacier/21469.jpg
#   inflating: seg_test/seg_test/glacier/24249.jpg
# ...

# %%
# Create a list of all test files
test = []
classes = os.listdir('seg_test/seg_test')
print(classes)
for x in classes:
  test.append(os.listdir('seg_test/seg_test/' + x))
# flatten out nested lists into a single list
test = [item for elem in test for item in elem]

test.insert(0, 'file_name') 
# print first ten images of the list
test[1:10]
# Out:
# ['glacier', 'forest', 'street', 'buildings', 'mountain', 'sea']
# ['22513.jpg',
#  '23714.jpg',
#  '21303.jpg',
#  '24113.jpg',
#  '20680.jpg',
#  '24096.jpg',
#  '20567.jpg',
#  '24152.jpg',
#  '23762.jpg']

# %%
with open('seg_test/test.csv', 'w') as f:
    writer = csv.writer(f)
    for file in test:
        writer.writerow([file])
